# %%
import time, re, os, sys, threading, math, multiprocessing, subprocess, pymongo
from datetime import datetime
import pandas as pd
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
import gspread
from oauth2client.service_account import ServiceAccountCredentials
from selenium.webdriver.common.action_chains import ActionChains

# pandas setting for displaying rows and columns
pd.options.display.max_columns = 999
pd.options.display.max_rows = 999

num = os.cpu_count()
driverPath = r'C:\Users\USER\chromedriver_win32\chromedriver.exe'


# chrome options 
chrome_options = Options()
prefs = {
    "download.open_pdf_in_system_reader": False,
    "download.prompt_for_download": True,
    "plugins.always_open_pdf_externally": False
}
chrome_options.add_experimental_option(
    "prefs", prefs
)

chrome_options.add_argument("window-size=1200,1100");
chrome_options.add_argument("--start-maximized")
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')



#calculating start time
start = datetime.now()
current_time = start.strftime("%H:%M:%S")

# use creds to create a client to interact with the Google Drive API
scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name('client_secret.json', scope)
client = gspread.authorize(creds)
# Find a workbook by name and open the first sheet
sheet = client.open("Automation - Social Media Check")
sheet = sheet.get_worksheet(1)
allRecords = sheet.get_all_records()


social_names = ['facebook', 'instagram', 'pinterest']
def removeSlash(target):
    name = target.rstrip(target[-1])
    return name

def updateCell(val, color):
    if color == 'green':
        sheet.update(val, 'V')
        sheet.format(val, {
            "backgroundColor": {
              "red":0,
              "green": 50,
              "blue": 0
            },
            "horizontalAlignment": "CENTER",
            "textFormat": {
              "foregroundColor": {
                "red": 1.0,
                "green": 1.0,
                "blue": 1.0
              },
              "fontSize": 12,
              "bold": False
            }
        })
    else:
        sheet.update(val, '')
        sheet.format(val, {
            "backgroundColor": {
              "red": 20,
              "green": 0,
              "blue": 0
            },
            "horizontalAlignment": "CENTER",
            "textFormat": {
              "foregroundColor": {
                "red": 1.0,
                "green": 1.0,
                "blue": 1.0
              },
              "fontSize": 12,
              "bold": False
            }
        })
        

def explicitVisit(socialUrl, socialType):
    global boolinsta
    global boolpin
    global boolfb
    global boolinsta1
    global boolpin1
    global boolfb1

    try:
        driver.get(socialUrl)
        time.sleep(1)
        explicitSocialLink = driver.current_url
        source = driver.page_source
        soup = BeautifulSoup(source, 'html.parser')
    except:
        print("Error in explicit domain get by driver")
        return

    if socialType == 'insta':
        boolinsta = False
        if "Sorry, this page isn't available" in str(soup):
            print("Instagram Error")
            boolinsta1 = False
        else:
            print("here 1")
            updateCell(instacellname1, 'green')
            boolinsta1 = True 
    
    elif socialType == 'pin':
        boolpin = False
        if 'show_error=true' in socialLink:
            print("error in pinterest ",socialLink)
            boolpin1 = False
            
        else:
            print("here 10")
            updateCell(pincellname1, 'green')
            boolpin1 = True
        
    elif socialType == 'fb':
        boolfb = False
        if "This Page Isn't Available" in str(soup):
            print("Facebook Error")
            boolfb1 = False
            
        else:
            print("here 11")
            updateCell(fbcellname1, 'green')
            boolfb1 = True
            
    print("quit in explicit ", i)
    return
        
    
        
for i in range(len(allRecords)):
    each = allRecords[i]
    num = i+2
    
    boolinsta = ''
    boolpin = ''
    boolfb = ''
    
    boolinsta1 = ''
    boolpin1 = ''
    boolfb1 = ''
    
    instabool = True
    pinbool = True
    fbbool = True
    
    
    driver = webdriver.Chrome(driverPath, chrome_options=chrome_options)
    domain = each["DOMAIN"]
    insta = each['Instagram']
    fb = each['Facebook']
    pin = each['Pinterest']

    
    try:
        eachDomain = "https://"+domain
        print("Visiting  >>>> ", eachDomain)
        print()
        driver.get(eachDomain)
        time.sleep(1)
    except:
        print("Error in getting domain by driver ::", eachDomain)
        driver.quit()
        continue
    
    nav = driver.find_elements_by_tag_name('nav')
    for eachNav in nav:
        divs = eachNav.find_elements(By.TAG_NAME, 'div') 
        for eachdiv in divs:
            finalDiv = eachdiv.find_elements(By.TAG_NAME, 'div')
            for eachFinalDiv in finalDiv:
                uls = eachFinalDiv.find_elements(By.TAG_NAME, 'ul')
                for eachUl in uls[1:]:
                    lis = eachUl.find_elements(By.TAG_NAME, 'li')
                    for eachli in lis[:1]:
                        allas = eachli.find_elements(By.TAG_NAME, 'a')
                        for i in range(len(allas)):
                            eachAs = allas[i]
                            
                            for social in social_names:
                                if social in eachAs.get_attribute('href'):
                                    linkDiv = eachAs.get_attribute('href')
                                    print(linkDiv)
                                    eachAs.click()  
                                    

    time.sleep(1)
    urlname = eachDomain.split("//")[1]
    name = urlname.split(".")[0]

    currentWindow = driver.current_window_handle
    print("Current window title: " + driver.title)
    print()
    chwd = driver.window_handles

    instacellname = 'D'+str(num)
    instacellname1 = 'E'+str(num)
    
    pincellname = 'G'+str(num)
    pincellname1 = 'H'+str(num)
    
    fbcellname = 'J'+str(num)
    fbcellname1 = 'K'+str(num)
    
    # #switch focus to child window
    for w in chwd:
        if(w!= currentWindow):
            driver.switch_to.window(w)
            socialLink = driver.current_url
            print("Current url : ", socialLink)
            
            if 'www' not in socialLink:
                chunks = socialLink.split("//")
                socialLink = chunks[0]+"//www."+chunks[1]
            if socialLink[-1] ==  '/':
                socialLink = removeSlash(socialLink)
            
            
            #INSTAGRAM
            if 'instagram' in  socialLink:
                instabool = False
                if socialLink in insta:
                    print("Valid instagram page link : ", socialLink, insta)
                    updateCell(instacellname, 'green')
                    boolinsta = True 
                else:
                    boolinsta = False 

                source = driver.page_source
                soup = BeautifulSoup(source, 'html.parser')
                if "Sorry, this page isn't available" in str(soup):
                    print("Instagram Error")
                    boolinsta1 = False 
                else:
                    updateCell(instacellname1, 'green')
                    boolinsta1 = True 
                    
                                        
            #PINTEREST
            elif 'pinterest' in socialLink:
                pinbool = False
                #onsite checker
                if socialLink in pin:
                    print("Valid pinterest page link : ", socialLink, pin)
                    updateCell(pincellname, 'green')
                    boolpin = True
                else:
                    boolpin = False
                    
                    
                #onlive checker
                if 'show_error=true' in socialLink:
                    print("error in pinterest ",socialLink)
                    boolpin1 = False
                else:
                    updateCell(pincellname1, 'green')
                    boolpin1 = True
                    
            #FACEBOOK   
            elif 'facebook' in socialLink:
                fbbool = False
                if socialLink in fb:
                    print("Valid facebook page link : ", socialLink, fb)
                    updateCell(fbcellname, 'green')
                    boolfb = True
                else:
                    boolfb = False
                    
                #onlive section
                source = driver.page_source
                soup = BeautifulSoup(source, 'html.parser')
                if "You must log in to continue." or "This Page Isn't Available" in str(soup):
                    print("Facebook Error")
                    boolfb1 = False
                else:
                    updateCell(fbcellname1, 'green')
                    boolfb1 = True
            else:
                print("Not a valid page link", socialLink)
            
    #Explicitly visit link and update onlive
    if instabool == True:
        print("Explicit visit for insta in domain : ", domain)
        res = explicitVisit(insta, 'insta')
        instabool = False
    if pinbool == True:
        print("Explicit visit for pin in domain : ", domain)
        res = explicitVisit(pin, 'pin')
        pinbool = False
    if fbbool == True:
        print("Explicit visit for fb in domain : ", domain)
        res = explicitVisit(fb, 'fb')
        fbbool = False
             
    #ONSITEBOOL
    if boolinsta == False:
        updateCell(instacellname, 'red')
    if boolpin == False:
        updateCell(pincellname, 'red')
    if boolfb == False:
        updateCell(fbcellname, 'red')
            
    #ONLIVEBOOL
    if boolinsta1 == False:
        updateCell(instacellname1, 'red')
    if boolpin1 == False:
        updateCell(pincellname1, 'red')
    if boolfb1 == False:
        updateCell(fbcellname1, 'red')
    
    driver.quit()
    print()     
    print()     
    print()     
    print()     
    print()
# Out:
# <ipython-input-3-09b09a17d0c9>:173: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(driverPath, chrome_options=chrome_options)
# Visiting  >>>>  https://magafitness.com
#
# https://instagram.com/magafitness1
# https://pinterest.com/newfitnessmagazine
# Current window title: MagaFitness | Best Fitness Tips , Routines and Products
#
# Current url :  https://www.pinterest.com/newfitnessmagazine/
# Valid pinterest page link :  https://www.pinterest.com/newfitnessmagazine https://www.pinterest.com/newfitnessmagazine/
# Current url :  https://www.instagram.com/magafitness1/
# Valid instagram page link :  https://www.instagram.com/magafitness1 https://www.instagram.com/magafitness1
# Explicit visit for fb in domain :  magafitness.com
# Error in explicit domain get by driver
#
#
#
#
#
# Visiting  >>>>  https://mygardenway.com
#
# https://instagram.com/mygardenway1
# https://pinterest.com/mygardenway
# Current window title: Home - mygardenway.com
#
# Current url :  https://www.pinterest.com/mygardenway/
# Valid pinterest page link :  https://www.pinterest.com/mygardenway https://www.pinterest.com/mygardenway/
# Current url :  https://www.instagram.com/mygardenway1/
# Valid instagram page link :  https://www.instagram.com/mygardenway1 https://www.instagram.com/mygardenway1
# Explicit visit for fb in domain :  mygardenway.com
# here 11
# quit in explicit  2
#
#
#
#
#
# Visiting  >>>>  https://myfishingtips.com
#
# https://instagram.com/myfishingtips
# https://pinterest.com/myfishingtips1
# https://facebook.com/My-Fishing-Tips-113149440438557
# Current window title: MyFishingTips | Fishing Tips & Trick
#
# Current url :  https://www.facebook.com/My-Fishing-Tips-113149440438557
# Valid facebook page link :  https://www.facebook.com/My-Fishing-Tips-113149440438557 https://www.facebook.com/My-Fishing-Tips-113149440438557
# Facebook Error
# Current url :  https://www.pinterest.com/myfishingtips1/
# Valid pinterest page link :  https://www.pinterest.com/myfishingtips1 https://www.pinterest.com/myfishingtips1/
# Current url :  https://www.instagram.com/myfishingtips/
# Valid instagram page link :  https://www.instagram.com/myfishingtips https://www.instagram.com/myfishingtips
#
#
#
#
#
# Visiting  >>>>  https://drgreenvibe.com
#
# https://instagram.com/drgreenvibe1
# https://pinterest.com/drgreenvibe
# https://facebook.com/104602671389506
# Current window title: Go Green | Solar Energy | Pollution & Recycling | Dr Green Vibe
#
# Current url :  https://www.facebook.com/Dr-Green-Vibe-104602671389506/
# Valid facebook page link :  https://www.facebook.com/Dr-Green-Vibe-104602671389506 https://www.facebook.com/Dr-Green-Vibe-104602671389506/
# Facebook Error
# Current url :  https://www.pinterest.com/drgreenvibe/
# Valid pinterest page link :  https://www.pinterest.com/drgreenvibe https://www.pinterest.com/drgreenvibe/
# Current url :  https://www.instagram.com/drgreenvibe1/
# Valid instagram page link :  https://www.instagram.com/drgreenvibe1 https://www.instagram.com/drgreenvibe1
#
#
#
#
#
# Visiting  >>>>  https://justtogrow.com
#
# https://instagram.com/justtogrow60
# https://pinterest.com/justtogrow
# Current window title: Self-Motivation | Self Growth | Self-Esteem | JustToGrow
#
# Current url :  https://www.pinterest.com/justtogrow/
# Valid pinterest page link :  https://www.pinterest.com/justtogrow https://www.pinterest.com/justtogrow1
# Current url :  https://www.instagram.com/justtogrow60/
# Valid instagram page link :  https://www.instagram.com/justtogrow60 https://www.instagram.com/justtogrow60
# Explicit visit for fb in domain :  justtogrow.com
# here 11
# quit in explicit  2
#
#
#
#
#
# Visiting  >>>>  https://thevpblog.com
#
# https://instagram.com/thevpblog_vintage
# https://pinterest.com/thevpblogphotography
# https://facebook.com/114342510318802
# Current window title: Vintage Photography Blog - Information, Guides and Tips - The VP Blog
#
# Current url :  https://www.facebook.com/The-VP-Blog-114342510318802/
# Valid facebook page link :  https://www.facebook.com/The-VP-Blog-114342510318802 https://www.facebook.com/The-VP-Blog-114342510318802/
# Facebook Error
# Current url :  https://www.pinterest.com/thevpblogphotography/
# Valid pinterest page link :  https://www.pinterest.com/thevpblogphotography https://www.pinterest.com/thevpblogphotography/
# Current url :  https://www.instagram.com/thevpblog_vintage/
# Valid instagram page link :  https://www.instagram.com/thevpblog_vintage https://www.instagram.com/thevpblog_vintage

# %%
driver = webdriver.Chrome(driverPath, chrome_options=chrome_options)
driver.get('https://www.facebook.com/The-VP-Blog-114102/')
source = driver.page_source
soup = BeautifulSoup(source, 'html.parser')
# Out:
# <ipython-input-18-d188b17f7b13>:1: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(driverPath, chrome_options=chrome_options)

# %%
soup.body.prettify().encode('utf-8')
# Out:
# b'<body class="fbx UIPage_LoggedOut _-kb _605a b_c3pyn-ahh chrome webkit win x1 Locale_en_GB cores-gte4 _19_u hasAXNavMenubar" dir="ltr">\n <script nonce="" type="text/javascript">\n  requireLazy(["bootstrapWebSession"],function(j){j(1628613502)})\n </script>\n <div class="_li" id="u_0_5_bZ">\n  <div class="_3_s0 _1toe _3_s1 _3_s1 uiBoxGray noborder" data-testid="ax-navigation-menubar" id="u_0_6_2F">\n   <div class="_608m">\n    <div class="_5aj7 _tb6">\n     <div class="_4bl7">\n      <span class="mrm _3bcv _50f3">\n       Jump to\n      </span>\n     </div>\n     <div class="_4bl9 _3bcp">\n      <div aria-keyshortcuts="Alt+/" aria-label="Navigation assistant" class="_6a _608n" id="u_0_7_+v" role="menubar">\n       <div class="_6a uiPopover" id="u_0_8_s8">\n        <a aria-expanded="false" aria-haspopup="true" class="_42ft _4jy0 _55pi _2agf _4o_4 _63xb _p _4jy3 _517h _51sy" href="#" id="u_0_9_nm" rel="toggle" role="menuitem" style="max-width:200px;">\n         <span class="_55pe">\n          Sections of this page\n         </span>\n         <span class="_4o_3 _3-99">\n          <i class="img sp_0rfy5QudR63 sx_b8050d">\n          </i>\n         </span>\n        </a>\n       </div>\n       <div class="_6a _3bcs">\n       </div>\n       <div class="_6a mrm uiPopover" id="u_0_a_eX">\n        <a aria-expanded="false" aria-haspopup="true" class="_42ft _4jy0 _55pi _2agf _4o_4 _3_s2 _63xb _p _4jy3 _4jy1 selected _51sy" href="#" id="u_0_b_rY" rel="toggle" role="menuitem" style="max-width:200px;" tabindex="-1">\n         <span class="_55pe">\n          Accessibility help\n         </span>\n         <span class="_4o_3 _3-99">\n          <i class="img sp_0rfy5QudR63 sx_c33de0">\n          </i>\n         </span>\n        </a>\n       </div>\n      </div>\n     </div>\n     <div class="_4bl7 mlm pll _3bct">\n      <div class="_6a _3bcy">\n       Press\n       <span class="_3bcz">\n        alt\n       </span>\n       +\n       <span class="_3bcz">\n        /\n       </span>\n       to open this menu\n      </div>\n     </div>\n    </div>\n   </div>\n  </div>\n  <div data-referrer="pagelet_bluebar" id="pagelet_bluebar">\n   <div id="blueBarDOMInspector">\n    <div class="_53jh">\n     <div class="loggedout_menubar_container">\n      <div class="clearfix loggedout_menubar">\n       <div class="lfloat _ohe">\n        <h1>\n         <a href="https://www.facebook.com/" title="Go to Facebook home">\n          <i class="fb_logo img sp_0rfy5QudR63 sx_7a1d9a">\n           <u>\n            Facebook\n           </u>\n          </i>\n         </a>\n        </h1>\n       </div>\n       <div class="menu_login_container rfloat _ohf" data-testid="royal_login_form">\n        <form action="https://www.facebook.com/login/device-based/regular/login/?login_attempt=1&amp;lwv=110" id="login_form" method="post" novalidate="1" onsubmit="">\n         <input autocomplete="off" name="jazoest" type="hidden" value="2947"/>\n         <input autocomplete="off" name="lsd" type="hidden" value="AVqlBG3oyk0"/>\n         <table cellspacing="0" role="presentation">\n          <tbody>\n           <tr>\n            <td class="html7magic">\n             <label for="email">\n              Email or phone\n             </label>\n            </td>\n            <td class="html7magic">\n             <label for="pass">\n              Password\n             </label>\n            </td>\n           </tr>\n           <tr>\n            <td>\n             <input class="inputtext login_form_input_box" data-testid="royal_email" id="email" name="email" type="email"/>\n            </td>\n            <td>\n             <input class="inputtext login_form_input_box" data-testid="royal_pass" id="pass" name="pass" type="password"/>\n            </td>\n            <td>\n             <label class="login_form_login_button uiButton uiButtonConfirm" for="u_0_2_mi" id="loginbutton">\n              <input aria-label="Log In" data-testid="royal_login_button" id="u_0_2_mi" type="submit" value="Log In"/>\n       ...

# %%
if "You must log in to continue." or "This Page Isn't Available" in str(soup):
    print("Error")
# Out:
# Error

# %%
        
        
        
#     if len(insta) == 0:
#         updateCell(instacellname, 'white')
#         updateCell(instacellname1, 'white')        
        
#     if len(pin) == 0:
#         updateCell(pincellname, 'white')
#         updateCell(pincellname1, 'white')
        
#     if len(fb) == 0:
#         updateCell(fbcellname, 'white')
#         updateCell(fbcellname1, 'white')

# %%
import time, re, os, sys, threading, math, multiprocessing, subprocess, pymongo
from datetime import datetime
import pandas as pd
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
from selenium.webdriver.chrome.options import Options
import gspread
from oauth2client.service_account import ServiceAccountCredentials
from selenium.webdriver.common.action_chains import ActionChains

# pandas setting for displaying rows and columns
pd.options.display.max_columns = 999
pd.options.display.max_rows = 999

num = os.cpu_count()
driverPath = r'C:\Users\USER\chromedriver_win32\chromedriver.exe'


# chrome options 
chrome_options = Options()
prefs = {
    "download.open_pdf_in_system_reader": False,
    "download.prompt_for_download": True,
    "plugins.always_open_pdf_externally": False
}
chrome_options.add_experimental_option(
    "prefs", prefs
)

chrome_options.add_argument("window-size=1200,1100");
chrome_options.add_argument("--start-maximized")
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')



#calculating start time
start = datetime.now()
current_time = start.strftime("%H:%M:%S")

# use creds to create a client to interact with the Google Drive API
scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name('client_secret.json', scope)
client = gspread.authorize(creds)
# Find a workbook by name and open the first sheet
sheet = client.open("Automation - Social Media Check")
sheet = sheet.get_worksheet(1)
allRecords = sheet.get_all_records()


social_names = ['facebook', 'instagram', 'pinterest']
def removeSlash(target):
    name = target.rstrip(target[-1])
    return name

def updateCell(val, color):
    if color == 'green':
        sheet.update(val, 'V')
        sheet.format(val, {
            "backgroundColor": {
              "red":0,
              "green": 50,
              "blue": 0
            },
            "horizontalAlignment": "CENTER",
            "textFormat": {
              "foregroundColor": {
                "red": 1.0,
                "green": 1.0,
                "blue": 1.0
              },
              "fontSize": 12,
              "bold": False
            }
        })
    elif color == 'red':
        sheet.update(val, '')
        sheet.format(val, {
            "backgroundColor": {
              "red": 20,
              "green": 0,
              "blue": 0
            },
            "horizontalAlignment": "CENTER",
            "textFormat": {
              "foregroundColor": {
                "red": 1.0,
                "green": 1.0,
                "blue": 1.0
              },
              "fontSize": 12,
              "bold": False
            }
        })
    else:
        sheet.update(val, '')
        sheet.format(val, {
            "backgroundColor": {
              "red": 255,
              "green": 255,
              "blue": 255
            },
            "horizontalAlignment": "CENTER",
            "textFormat": {
              "foregroundColor": {
                "red": 255,
                "green": 255,
                "blue": 255,
              },
              "fontSize": 1,
              "bold": False
            }
        })
        
        

def explicitVisit(socialUrl, socialType):
    global boolinsta1
    global boolpin1
    global boolfb1

    try:
        driver.get(socialUrl)
        time.sleep(1)
        explicitSocialLink = driver.current_url
        source = driver.page_source
        soup = BeautifulSoup(source, 'html.parser')
    except:
        print("Error in explicit domain get by driver")
        return

    if socialType == 'insta':
        if "Sorry, this page isn't available" in str(soup):
            print("Instagram Error")
        else:
            print("here 1")
            updateCell(instacellname1, 'green')
            boolinsta1 = True 
    
    elif socialType == 'pin':
        if 'show_error=true' in socialLink:
            print("error in pinterest ",socialLink)
        else:
            print("here 10")
            updateCell(pincellname1, 'green')
            boolpin1 = True
        
    elif socialType == 'fb':
        if "This Page Isn't Available" in str(soup):
            print("Facebook Error")
        else:
            print("here 11")
            updateCell(fbcellname1, 'green')
            boolfb1 = True
    print("quit in explicit ", i)
    return
    
        
for i in range(len(allRecords)):
    each = allRecords[i]
    num = i+2
    
    boolinsta = False
    boolpin = False
    boolfb = False
    
    boolinsta1 = False
    boolpin1 = False
    boolfb1 = False
    
    instabool = True
    pinbool = True
    fbbool = True
    
    
    driver = webdriver.Chrome(driverPath, chrome_options=chrome_options)
    domain = each["DOMAIN"]
    insta = each['Instagram'].strip()
    fb = each['Facebook'].strip()
    pin = each['Pinterest'].strip()

    
    try:
        eachDomain = "https://"+domain
        print("Visiting  >>>> ", eachDomain)
        print()
        driver.get(eachDomain)
        time.sleep(1)
    except:
        print("Error in getting domain by driver ::", eachDomain)
        driver.quit()
        continue
    
    nav = driver.find_elements_by_tag_name('nav')
    for eachNav in nav:
        divs = eachNav.find_elements(By.TAG_NAME, 'div') 
        for eachdiv in divs:
            finalDiv = eachdiv.find_elements(By.TAG_NAME, 'div')
            for eachFinalDiv in finalDiv:
                uls = eachFinalDiv.find_elements(By.TAG_NAME, 'ul')
                for eachUl in uls[1:]:
                    lis = eachUl.find_elements(By.TAG_NAME, 'li')
                    for eachli in lis[:1]:
                        allas = eachli.find_elements(By.TAG_NAME, 'a')
                        for i in range(len(allas)):
                            eachAs = allas[i]
                            
                            for social in social_names:
                                if social in eachAs.get_attribute('href'):
                                    linkDiv = eachAs.get_attribute('href')
                                    print(linkDiv)
                                    eachAs.click()  
                                    

    time.sleep(1)
    urlname = eachDomain.split("//")[1]
    name = urlname.split(".")[0]

    currentWindow = driver.current_window_handle
    print("Current window title: " + driver.title)
    print()
    chwd = driver.window_handles

    instacellname = 'D'+str(num)
    instacellname1 = 'E'+str(num)
    
    pincellname = 'G'+str(num)
    pincellname1 = 'H'+str(num)
    
    fbcellname = 'J'+str(num)
    fbcellname1 = 'K'+str(num)
    
    # #switch focus to child window
    for w in chwd:
        if(w!= currentWindow):
            driver.switch_to.window(w)
            socialLink = driver.current_url
            print("Current url : ", socialLink)
            
            if 'www' not in socialLink:
                chunks = socialLink.split("//")
                socialLink = chunks[0]+"//www."+chunks[1]
            if socialLink[-1] ==  '/':
                socialLink = removeSlash(socialLink)
            
            
            #INSTAGRAM
            if 'instagram' in  socialLink:
                instabool = False
                if len(insta) == 0:
                    print("Length is zero : ", insta, " So lets mark red all the columns")
                    updateCell(instacellname, 'white')
                    updateCell(instacellname1, 'white')
                    boolinsta = True
                    boolinsta1 = True
                    
                else:
                    if socialLink in insta:
                        print("Valid instagram page link : ", socialLink, insta)
                        updateCell(instacellname, 'green')
                        boolinsta = True 

                    source = driver.page_source
                    soup = BeautifulSoup(source, 'html.parser')
                    if "Sorry, this page isn't available" in str(soup):
                        print("Instagram Error")
                    else:
                        updateCell(instacellname1, 'green')
                        boolinsta1 = True 

                                        
            #PINTEREST
            elif 'pinterest' in socialLink:
                pinbool = False
                if len(pin) == 0:
                    print("Length is zero in pin : ", pin, " So lets mark red all the columns")
                    updateCell(pincellname, 'white')
                    updateCell(pincellname1, 'white')
                    boolpin = True
                    boolpin1 = True
                else:
                    #onsite checker
                    if socialLink in pin:
                        print("Valid pinterest page link : ", socialLink, pin)
                        updateCell(pincellname, 'green')
                        boolpin = True

                    #onlive checker
                    if 'show_error=true' in socialLink:
                        print("error in pinterest ",socialLink)
                    else:
                        updateCell(pincellname1, 'green')
                        boolpin1 = True
                    
            #FACEBOOK   
            elif 'facebook' in socialLink:
                fbbool = False
                if len(fb) == 0:
                    print("Length is zero in fb : ", fb, " So lets mark red all the columns")
                    updateCell(fbcellname, 'white')
                    updateCell(fbcellname1, 'white')
                    boolfb = True
                    boolfb1 = True
                else:
                    if socialLink in fb:
                        print("Valid facebook page link : ", socialLink, fb)
                        updateCell(fbcellname, 'green')
                        boolfb = True

                    #onlive section
                    source = driver.page_source
                    soup = BeautifulSoup(source, 'html.parser')
                    if "This Page Isn't Available" in str(soup):
                        print("Facebook Error")
                    else:
                        updateCell(fbcellname1, 'green')
                        boolfb1 = True
            else:
                print("Not a valid page link", socialLink)
            
    #Explicitly visit link and update onlive
    if instabool == True:
        print("Explicit visit for insta in domain : ", domain)
        res = explicitVisit(insta, 'insta')
        instabool = False
    if pinbool == True:
        print("Explicit visit for pin in domain : ", domain)
        res = explicitVisit(pin, 'pin')
        pinbool = False
    if fbbool == True:
        print("Explicit visit for fb in domain : ", domain)
        res = explicitVisit(fb, 'fb')
        fbbool = False
             
            
    #ONSITEBOOL
    if boolinsta == False:
        updateCell(instacellname, 'red')
    if boolpin == False:
        updateCell(pincellname, 'red')
    if boolfb == False:
        updateCell(fbcellname, 'red')
            
    #ONLIVEBOOL
    if boolinsta1 == False:
        updateCell(instacellname1, 'red')
    if boolpin1 == False:
        updateCell(pincellname1, 'red')
    if boolfb1 == False:
        updateCell(fbcellname1, 'red')
    
    driver.quit()
    print()     
    print()     
    print()     
    print()     
    print()
